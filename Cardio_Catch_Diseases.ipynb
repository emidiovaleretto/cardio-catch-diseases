# %%
Image('img/cardio.jpg')

# %% [markdown]
# <h1> Cardiovascular Diseases (CVDs)</h1>

# %% [markdown]
# <br>

# %% [markdown]
# <h1> | Overview </h1>

# %% [markdown]
# <h3> Small causes with great effects </h3>
#
# Cardiovascular disease (CVDs) is a generic term for all pathological changes that affect the heart and/or blood vessels. The term includes coronary heart disease (a disease that affects the blood vessels that supply the heart), hypertension and atherosclerosis. One of the most important risk factors for cardiovascular disease is hypertension (high blood pressure).
#
# Prolonged high blood pressure leads to changes in blood vessel walls that interfere with blood flow and result in the heart not receiving enough oxygen. The heart reacts with pain, which is called angina pectoris (which literally means "tightness in the chest").
#
# The complete blockage of blood flow results in a myocardial infarction (a heart attack). This is, in general, a consequence of advanced coronary arteriosclerosis.
#
# <h3> Important factors </h3>
#
# In the year 2000, cardiovascular diseases were the cause of about one-third of all deaths worldwide. Cardiovascular diseases and cancer are the main causes of death in industrialized countries. That is 2010 cardiovascular diseases will also have become the main cause of death in developing countries.
#
# Cardiovascular diseases are a group of diseases of the heart and blood vessels and include:
#
#   - **Coronary heart disease** - disease of the blood vessels that supply the heart muscle;
#   - **Cerebrovascular disease** - disease of the blood vessels that supply the brain;
#   - **Peripheral arterial disease** - disease of the blood vessels that supply the upper and lower limbs;
#   - **Rheumatic heart disease** - damage to the heart muscle and heart valves due to rheumatic fever, caused by streptococcal bacteria;
#   - **Congenital heart disease** - malformations in the structure of the heart that has existed since birth;
#   - **Deep vein thrombosis and pulmonary embolism** - blood clots in the leg veins, which can dislodge and move to the heart and lungs.

# %% [markdown]
# <h1> | Global Statistics </h1>

# %% [markdown]
# Cardiovascular diseases are the **leading cause of death in the world**: more people die annually from these diseases than from any other cause.
#
# It is estimated that **17.9 million people** died from cardiovascular disease in 2016, representing **31% of all deaths globally**. Of these deaths, it is estimated that 85% occur due to heart attacks and strokes (strokes).
#
# **More than three quarters of deaths** from cardiovascular disease occur in low- and middle-income countries.
#
# Of the **17 million premature deaths** (people under the age of 70) from chronic non-communicable diseases, **82%** occur in low and middle income countries and **37%** are caused by cardiovascular diseases.

# %% [markdown]
# <h3> What are the risk factors for cardiovascular disease? </h3>

# %%
Image('img/cardio2.jpg')

# %% [markdown]
# The most important behavioural risk factors of heart disease and stroke are **unhealthy diet, physical inactivity, tobacco use and harmful use of alcohol**. The effects of behavioural risk factors may show up in individuals as **raised blood pressure**, raised blood glucose, raised blood lipids, and **overweight** and **obesity**. These “intermediate risks factors” can be measured in primary care facilities and indicate an increased risk of developing a heart attack, stroke, heart failure and other complications.
#
# Cessation of tobacco use, reduction of salt in the diet, consuming fruits and vegetables, regular physical activity and avoiding harmful use of alcohol have been shown to reduce the risk of cardiovascular disease. In addition, drug treatment of diabetes, hypertension and high blood lipids may be necessary to reduce cardiovascular risk and prevent heart attacks and strokes.
#
# Health policies that create conducive environments for making healthy choices affordable and available are essential for motivating people to adopt and sustain healthy behaviour.
#
# There are also a number of underlying determinants of CVDs or "the causes of the causes". These are a reflection of the major forces driving social, economic and cultural change – globalization, urbanization and population ageing. Other determinants of CVDs include poverty, stress and hereditary factors.

# %%
Image('img/blood_pressure.jpg')

# %% [markdown]
# Source: https://www.who.int/news-room/fact-sheets/detail/cardiovascular-diseases-(cvds)

# %% [markdown]
# <br>

# %% [markdown]
# <h1> | Business Problem </h1>

# %% [markdown]
#  - *Disclaimer: The following context is totally fictional, the company, the context, the CEO and the business questions exist only to give shape to the problem.*

# %% [markdown]
# <h3> Cardio Catch Diseases (CCD) </h3>
#
# The Cardio Catch Diseases (CCD) Company
# Cardio Catch Diseases is a company that specializes in detecting heart disease in the early stages. Its business model is Service type, that is, the company offers an early diagnosis of cardiovascular disease for a certain price.
#
# Currently, the diagnosis of cardiovascular disease is made manually by a team of specialists. The current accuracy of the diagnosis varies between 55% and 65%, due to the complexity of the diagnosis and also the fatigue of the team who take turns to minimize the risks. The cost of each diagnosis, including the devices and the payroll of the analysts, is around €1,000.00.
#
# The price of the diagnosis, paid by the client, varies according to the precision achieved by the team of specialists, the client pays €500.00 for each 5% accuracy above 50%. For example, for an accuracy of 55%, the diagnosis costs €500.00 for the client, for an accuracy of 60%, the value is €1000.00 and so on. If the diagnostic accuracy is 50%, the customer does not pay for it.
#
# Note that the variation in precision given by the team of specialists makes the company either have an operation with a profit, revenue greater than the cost, or an operation with a loss, revenue less than the cost. This instability of the diagnosis makes the company have an unpredictable Cashflow.
#
# My objective as a Data Scientist hired by Cardio Catch Diseases is to create a tool that increases the accuracy of the diagnosis and that this accuracy is stable for all diagnoses.
#
# So my job is to create a patient classification tool, with a stable accuracy. Along with the tool, you need to send a report to the CEO of Cardio Catch Diseases, reporting the results and answering the following questions:
#
# *(He will probably ask when I present the results of the work.)*
#
#   - What is the Accuracy and Precision of the tool?
#   - How much profit will Cardio Catch Diseases have with the new tool?
#   - How Reliable is the result given by the new tool?

# %% [markdown]
# <h1>| Challenge Data </h1>
#
# The dataset that will be used to create a solution to Cardio Catch Diseases is available on the Kaggle platform.
#
#  - Source: https://www.kaggle.com/sulianova/cardiovascular-disease-dataset
#
# The dataset contains 70,000 patient diagnoses. I will use this data to create the solution.

# %% [markdown]
# Reference: https://sejaumdatascientist.com/projeto-de-data-science-diagnostico-precoce-de-doencas-cardiovasculares/ (The article was written in Portuguese)

# %% [markdown]
# <br>

# %% [markdown]
# <h1> | Index </h1>
#
#   - 0.0. IMPORTS
#   - 1.0. DATA DESCRIPTION
#   - 2.0. FEATURE ENGINEERING
#   - 3.0. DATA FILTERING
#   - 4.0. EXPLORATORY DATA ANALYSIS
#   - 5.0. DATA PREPARATION
#   - 7.0. FEATURE SELECTION
#   - 8.0. MACHINE LEARNING MODEL

# %% [markdown]
# <br>

# %% [markdown]
# # 0.0. IMPORTS

# %%
import pandas                as pd
import numpy                 as np
import matplotlib.pyplot     as plt
import seaborn               as sns

from IPython.core.display    import HTML
from warnings                import filterwarnings

from IPython.display         import Image


filterwarnings('ignore')

# %% [markdown]
# ## 0.1. Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2. Loading Data

# %%
df_raw = pd.read_csv('data/cardio_train.csv', sep=';', low_memory=True)

# %% [markdown]
# # 1.0. DATA DESCRIPTION

# %%
df1 = df_raw.copy()

# %%
df1.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  cardio
# 0   0  18393       2     168    62.0    110     80            1     1      0     0       1       0
# 1   1  20228       1     156    85.0    140     90            3     1      0     0       1       1
# 2   2  18857       1     165    64.0    130     70            3     1      0     0       0       1
# 3   3  17623       2     169    82.0    150    100            1     1      0     0       1       1
# 4   4  17474       1     156    56.0    100     60            1     1      0     0       0       0

# %% [markdown]
# ## 1.1. Data Dimension

# %%
print(f'Number of rows: {df1.shape[0]}')
print(f'Number of columns: {df1.shape[1]}')
# Out:
# Number of rows: 70000
# Number of columns: 13

# %% [markdown]
# <h3>Data description</h3>
#
# There are 3 types of input features:
#
# Objective: factual information;
# Examination: results of medical examination;
# Subjective: information given by the patient.
# Features:
#
#   - Age    | Objective Feature | age    | int (days)
#   - Height | Objective Feature | height | int (cm) |
#   - Weight | Objective Feature | weight | float (kg) |
#   - Gender | Objective Feature | gender | categorical code |
#   - Systolic blood pressure  | Examination Feature | ap_hi | int |
#   - Diastolic blood pressure | Examination Feature | ap_lo | int |
#   - Cholesterol              | Examination Feature | cholesterol | 1: normal, 2: above normal, 3: well above normal |
#   - Glucose                  | Examination Feature | gluc  | 1: normal, 2: above normal, 3: well above normal |
#   - Smoking                  | Subjective Feature  | smoke | binary |
#   - Alcohol intake           | Subjective Feature  | alco  | binary |
#   - Physical activity        | Subjective Feature  | active| binary |
#   - Presence or absence of cardiovascular disease  | Target Variable| cardio | binary |
#
#
# All of the dataset values were collected at the moment of medical examination.

# %% [markdown]
# ## 1.2. Data Types

# %%
df1.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# ## 1.3. Check N/A's

# %%
df1.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ## 1.4. Fillout N/A's

# %% [markdown]
#    - Theres is no null data to be filled.

# %% [markdown]
# ## 1.5. Change Types

# %%
# According to the dataset, the variable 'age' is counted in days, therefore I will divide it into 365 to get the age properly.
# e.g. 18393 / 365 = 50.391 | Since it returns a float number, I will convert it into an integer number, getting like 50 rounded.
df1['age'].head()
# Out:
# 0    18393
# 1    20228
# 2    18857
# 3    17623
# 4    17474
# Name: age, dtype: int64

# %%
df1['age'] = df1['age'].apply(lambda x: x/365).astype(int)
df1['id'] = df1['id'].astype('object')
df1['height'] = df1['height'].astype('float64')

# %% [markdown]
# ## 1.6. Rename Columns

# %%
df1.rename(columns={'gluc': 'glucose',
                    'smoke': 'smoking',
                    'alco': 'alcohol_intake',
                    'active': 'physical_activity'}, inplace=True)

# %% [markdown]
# ## 1.7. Descriptive Statistics

# %%
num_attr = df1.select_dtypes(exclude=['object'])

# %% [markdown]
# ### 1.7.1. Numerical Attributes

# %%
# dropping those variables because they represent 0 and 1
num_attr.drop(columns=['age', 'gender', 'smoking', 'cholesterol', 'glucose','alcohol_intake', 'physical_activity', 'cardio'], inplace=True)

# Central Tendency - mean, median
ct1 = pd.DataFrame(num_attr.apply(np.mean)).T
ct2 = pd.DataFrame(num_attr.apply(np.median)).T

# Dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attr.apply(np.std)).T
d2 = pd.DataFrame(num_attr.apply(min)).T
d3 = pd.DataFrame(num_attr.apply(max)).T
d4 = pd.DataFrame(num_attr.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attr.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attr.apply(lambda x: x.kurtosis())).T

# Concatenate
ct = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
ct.columns = ['attributes', 'min', 'max', 'mean', 'median', 'std', 'range', 'skew', 'kurtosis']
ct
# Out:
#   attributes    min      max     mean      median    std       range       skew     kurtosis
# 0     height   55.0    250.0    195.0  164.359229  165.0    8.210068  -0.642187     7.943653
# 1     weight   10.0    200.0    190.0   74.205690   72.0   14.395654   1.012070     2.586825
# 2      ap_hi -150.0  16020.0  16170.0  128.817286  120.0  154.010319  85.296214  7580.074738
# 3      ap_lo  -70.0  11000.0  11070.0   96.630414   80.0  188.471184  32.114083  1425.914585

# %% [markdown]
# ### 1.7.2 Binary Attributes

# %%
binary_attr = df1[['smoking', 'cholesterol', 'glucose', 'alcohol_intake', 'physical_activity', 'cardio']]

# %%
plt.subplot(2, 3, 1);
sns.countplot(binary_attr['smoking']);

plt.subplot(2, 3, 2);
sns.countplot(binary_attr['cholesterol']);

plt.subplot(2, 3, 3);
sns.countplot(binary_attr['glucose']);

plt.subplot(2, 3, 4);
sns.countplot(binary_attr['alcohol_intake']);

plt.subplot(2, 3, 5);
sns.countplot(binary_attr['physical_activity']);

plt.subplot(2, 3, 6);
sns.countplot(binary_attr['cardio']);

# %% [markdown]
# # 2.0. FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Mind Map Hypotheses

# %%
Image('img/mindmap.png')

# %% [markdown]
# ## 2.2. Hypotheses List

# %% [markdown]
# ### 2.2.1. Age

# %% [markdown]
# 1. People over 21 and under 40 who smoking excessively are more likely to develop cardiovascular diseases.
# 2. People over 40 and under 60 are more likely to suffer from cardiovascular diseases.
# 3. People under 16 are less likely to develop cardiovascular diseases.
# 4. Seniors are more likely to suffer from cardiovascular diseases and the risk of developing it increases as you get older.
# 5. Adults age 65 and older are more likely than younger people to suffer from cardiovascular disease.

# %% [markdown]
# ### 2.2.2. Gender

# %% [markdown]
# 1. Men are more likely to develop cardiovascular diseases.
# 2. At younger ages, men face a greater risk of cardiovascular disease than women.
# 3. Women over 65 are more likely to have a first heart attack.
# 4. Middle-aged men have more heart attacks than women.
# 5. Women are almost twice as likely to have a second heart attack.

# %% [markdown]
# ### 2.2.3. Weight/Obesity

# %% [markdown]
# 1. People on underweight are less likely to develop cardiovascular diseases.
# 2. People on normal weight are less likely to delevop cardiovascular diseases.
# 3. People on overweight are more likely to develop cardiovascular diseases.
# 4. People on obesity (stage I) are more likely to have a heart attack.
# 5. People on obesity (stage II) are more likely to have a heart attack.
# 6. People who suffer from morbid obesity are very likely to have a heart attack.

# %% [markdown]
# ### 2.2.4. Physical Activity

# %% [markdown]
# 1. People who have a sedentary lifestyle are more likely to develop cardiovascular diseases.
# 2. People who have an active lifestyle are less likely to suffer a heart attack.
# 3. People who have a very active lifestyle are less likely to suffer a heart attack.

# %% [markdown]
# ### 2.2.5. Alcohol Intake

# %% [markdown]
# * Disclaimer: A new global study published has confirmed previous research which has shown that **there is no safe level of alcohol consumption**.*
#
# 1. People who use to consume at least a glass of wine a week are less likely to suffer a heart attack.
# 2. People who use to consume at least a pint of beer a day are more likely to develop cardiovascular diseases.
# 3. People who consume stronger beverages such as whiskey (usually 40% of alcohol) are more likely to develop cardiovascular diseases.
# 4. People who do not consume any kind of alcoholic beverages are less likely to develop cardiovascular diseases.
# 5. People who have excessive consumption of alcoholic beverages are very likely to develop cardiovascular diseases.¹

# %% [markdown]
# ¹ *Women who consume **eight** or **more drinks** per week are considered **excessive drinkers**. And for men, excess is defined as **15** or **more drinks** a week.*

# %% [markdown]
# ### 2.2.6. Smokers

# %% [markdown]
# 1. People who do not smoke are less likely to develop cardiovascular diseases.
# 2. People who are considered "social smoker" are likely to develop cardiovascular diseases.
# 3. People who are considered "occasional smoker" are more likely to have a heart attack.
# 4. People who are considered "daily smoker" are more likely to have cardiovascular disease.
# 5. Social smoker and occasional smoker carry nearly the same risk to develop cardiovascular disease as a daily smoker.
# 6. Excessive smokers are very likely to suffer a heart attack.

# %% [markdown]
# ### 2.2.7. Blood Pressure

# %% [markdown]
# 1. People with normal blood pressure are less likely to develop cardiovascular diseases.
# 2. People with elevated blood pressure are more likely than the normal blood pressure to develop cardiovascular diseases.
# 3. People with Hypertension (stage I) are more than likely to have a heart attack.
# 4. People with Hypertension (stage II) are very likely to have a heart attack.
# 5. People with the Hypertensive Crisis **MUST** contact their doctor **immediately**.

# %% [markdown]
# ## 2.3. Priority Hypotheses

# %% [markdown]
#  - H1. People over 40 and under 60 are more likely to suffer from cardiovascular diseases.
#  - H2. Seniors are more likely to suffer from cardiovascular diseases and the risk of developing it increases as you get older.
#  - H3. Adults age 65 and older are more likely than younger people to suffer from cardiovascular disease.
#  - H4. Men are more likely to develop cardiovascular diseases.
#  - H5. At younger ages, men face a greater risk of cardiovascular disease than women.
#  - H6. Women over 65 are more likely to have a first heart attack.
#  - H7. People on normal weight are less likely to delevop cardiovascular diseases.
#  - H8. People on obesity (stage I) are more likely to have a heart attack.
#  - H9. People on obesity (stage II) are more likely to have a heart attack.
#  - H10. People who suffer from morbid obesity are very likely to have a heart attack.
#  - H11. People who have a sedentary lifestyle are more likely to develop cardiovascular diseases.
#  - H12. People who have an active lifestyle are less likely to suffer a heart attack.
#  - H13. People who do not consume any kind of alcoholic beverages are less likely to develop cardiovascular diseases.
#  - H14. People who have excessive consumption of alcoholic beverages are very likely to develop cardiovascular diseases.
#  - H15. Social smoker and occasional smoker carry nearly the same risk to develop cardiovascular disease as a daily smoker.
#  - H16. Excessive smokers are very likely to suffer a heart attack.
#  - H17. People with normal blood pressure are less likely to develop cardiovascular diseases.
#  - H18. People with elevated blood pressure are more likely than the normal blood pressure to develop cardiovascular diseases.
#  - H19. People with Hypertension (stage I) are more than likely to have a heart attack.
#  - H20. People with Hypertension (stage II) are very likely to have a heart attack.

# %% [markdown]
# ## 2.4. Deriving New Features

# %%
df2['blood_pressure'] = df2.apply(lambda x: 'normal' if (x['ap_hi'] <= 120) & (x['ap_lo'] <= 80) 
                                 else 'elevated' if (x['ap_hi'] > 120 and x['ap_hi'] <= 129) & (x['ap_lo'] < 80)
                                 else 'high_blood_pressure' if (x['ap_hi'] >= 130 and x['ap_hi'] <= 139) | (x['ap_lo'] > 80 and x['ap_lo'] <= 89)
                                 else 'hypertension', axis=1)

# bmi formula is BMI = weight / height * height
## as the height is in cm, is needed to convert it into the square meter. Therefore, we divide the result of BMI by 10.000.
df2['bmi'] = round(df2['weight'] / ((df2['height'] ** 2) / 10000), 2)

df2['category_bmi'] = df2['bmi'].apply(lambda x: 'underweight' if x <= 18.5
                                              else 'normal' if (x >= 18.5) & (x < 25)
                                              else 'overweight' if (x >= 25) & (x < 30)
                                              else 'obese_I' if (x >= 30) & (x < 35)
                                              else 'obese_II' if (x >= 35) & (x < 40)
                                              else 'morbid_obesity')

df2['age_group'] = df2['age'].apply(lambda x: 'young' if (x >= 16) & (x <= 21)
                                           else 'adult' if (x > 21) & (x <= 40)
                                           else 'middle_age' if (x > 40) & (x <= 60)
                                           else 'seniors')

# %%
df2.sample(10)
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoking  alcohol_intake  physical_activity  cardio       blood_pressure    bmi category_bmi   age_group
# 69954  99938   41       1   170.0    60.0    120     80            2        1        0               0                  1       0               normal  20.76       normal  middle_age
# 38476  54935   52       1   155.0    58.0    100     70            1        1        0               0                  1       1               normal  24.14       normal  middle_age
# 18099  25848   52       1   155.0    70.0    120     80            2        1        0               0                  1       0               normal  29.14   overweight  middle_age
# 69319  99005   40       1   156.0    53.0     90     60            1        1        0               0                  0       0               normal  21.78       normal       adult
# ...
